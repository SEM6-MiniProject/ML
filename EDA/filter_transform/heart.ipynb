# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\salman\OneDrive\Desktop\SEM 6\ML\datasets\heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   52    1   0       125   212    0        1      168      0      1.0    2
# 1   53    1   0       140   203    1        0      155      1      3.1    0
# 2   70    1   0       145   174    0        1      125      1      2.6    0
# 3   61    1   0       148   203    0        1      161      0      0.0    2
# 4   62    0   0       138   294    1        1      106      0      1.9    1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df2 = pd.read_csv(r'C:\Users\salman\OneDrive\Desktop\SEM 6\ML\datasets\heart_attack_analysis_&_prediction\heart.csv')

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   63    1   3       145   233    1        0      150      0      2.3    0
# 1   37    1   2       130   250    0        1      187      0      3.5    0
# 2   41    0   1       130   204    0        0      172      0      1.4    2
# 3   56    1   1       120   236    0        1      178      0      0.8    2
# 4   57    0   0       120   354    0        1      163      1      0.6    2
#
#    ca  thal  output
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df2['output'].value_counts()
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64

# %%
df2['target'] = df2['output']

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   63    1   3       145   233    1        0      150      0      2.3    0
# 1   37    1   2       130   250    0        1      187      0      3.5    0
# 2   41    0   1       130   204    0        0      172      0      1.4    2
# 3   56    1   1       120   236    0        1      178      0      0.8    2
# 4   57    0   0       120   354    0        1      163      1      0.6    2
#
#    ca  thal  output  target
# 0   0     1       1       1
# 1   0     2       1       1
# 2   0     2       1       1
# 3   0     2       1       1
# 4   0     2       1       1

# %%
df2.drop('output', axis=1, inplace=True)

# %%
merged = pd.concat([df, df2])

# %%
# remove duplicates
merged.drop_duplicates(inplace=True)

# %%
merged.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   52    1   0       125   212    0        1      168      0      1.0    2
# 1   53    1   0       140   203    1        0      155      1      3.1    0
# 2   70    1   0       145   174    0        1      125      1      2.6    0
# 3   61    1   0       148   203    0        1      161      0      0.0    2
# 4   62    0   0       138   294    1        1      106      0      1.9    1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
merged.shape
# Out:
# (302, 14)

# %%
merged['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   52    1   0       125   212    0        1      168      0      1.0    2
# 1   53    1   0       140   203    1        0      155      1      3.1    0
# 2   70    1   0       145   174    0        1      125      1      2.6    0
# 3   61    1   0       148   203    0        1      161      0      0.0    2
# 4   62    0   0       138   294    1        1      106      0      1.9    1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   63    1   3       145   233    1        0      150      0      2.3    0
# 1   37    1   2       130   250    0        1      187      0      3.5    0
# 2   41    0   1       130   204    0        0      172      0      1.4    2
# 3   56    1   1       120   236    0        1      178      0      0.8    2
# 4   57    0   0       120   354    0        1      163      1      0.6    2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df2.equals(df)
# Out:
# False

# %%
df2.shape
# Out:
# (303, 14)

# %%
# intersection of two dataframes df and df2 on the basis of common columns
df3 = pd.merge(df, df2, how='outer')

# %%
df3.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   52    1   0       125   212    0        1      168      0      1.0    2
# 1   52    1   0       125   212    0        1      168      0      1.0    2
# 2   52    1   0       125   212    0        1      168      0      1.0    2
# 3   52    1   0       125   212    0        1      168      0      1.0    2
# 4   53    1   0       140   203    1        0      155      1      3.1    0
#
#    ca  thal  target
# 0   2     3       0
# 1   2     3       0
# 2   2     3       0
# 3   2     3       0
# 4   0     3       0

# %%
df3.shape
# Out:
# (1033, 14)

# %%
df.shape, df2.shape, df3.shape
# Out:
# ((1025, 14), (303, 14), (1033, 14))

# %%
# remove duplicates row from df2

df2.drop_duplicates(inplace=True)

# %%
df2.shape
# Out:
# (302, 14)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (302, 14)

# %%
df3.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0   52    1   0       125   212    0        1      168      0      1.0    2
# 1   52    1   0       125   212    0        1      168      0      1.0    2
# 2   52    1   0       125   212    0        1      168      0      1.0    2
# 3   52    1   0       125   212    0        1      168      0      1.0    2
# 4   53    1   0       140   203    1        0      155      1      3.1    0
#
#    ca  thal  target
# 0   2     3       0
# 1   2     3       0
# 2   2     3       0
# 3   2     3       0
# 4   0     3       0

# %%
# check duplicates in df3
df3.duplicated().sum()
# Out:
# 731

# %%
# remove duplicates from df3
df3.drop_duplicates(inplace=True)

# %%
df3.shape
# Out:
# (302, 14)

# %%
df3.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0    52    1   0       125   212    0        1      168      0      1.0    2
# 4    53    1   0       140   203    1        0      155      1      3.1    0
# 8    70    1   0       145   174    0        1      125      1      2.6    0
# 12   61    1   0       148   203    0        1      161      0      0.0    2
# 16   62    0   0       138   294    1        1      106      0      1.9    1
#
#     ca  thal  target
# 0    2     3       0
# 4    0     3       0
# 8    0     3       0
# 12   1     3       0
# 16   3     2       0

# %%
df3.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak         slp          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 1030
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slp       302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
df3.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slp         0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df3['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
df3.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slp         0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df3.to_csv(r'C:\Users\salman\OneDrive\Desktop\SEM 6\ML\datasets\transform\heart.csv', index=False)

# %%
df3.shape
# Out:
# (302, 14)

# %%
df3.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slp  \
# 0    52    1   0       125   212    0        1      168      0      1.0    2
# 4    53    1   0       140   203    1        0      155      1      3.1    0
# 8    70    1   0       145   174    0        1      125      1      2.6    0
# 12   61    1   0       148   203    0        1      161      0      0.0    2
# 16   62    0   0       138   294    1        1      106      0      1.9    1
#
#     ca  thal  target
# 0    2     3       0
# 4    0     3       0
# 8    0     3       0
# 12   1     3       0
# 16   3     2       0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 1030
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slp       302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
df3['cp'].value_counts()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
# draw a countplot
sns.countplot(x='cp', data=df3)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
df3['thal'].value_counts()
# Out:
# 2    165
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64
